# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# **load the csv**

# %%
#code here
df=pd.read_csv('/content/titanic_full.csv')

# %%
df
# Out:
#       Pclass      Fare  Survived
# 0          3    7.2500         0
# 1          1   71.2833         1
# 2          3    7.9250         1
# 3          1   53.1000         1
# 4          3    8.0500         0
# ...      ...       ...       ...
# 1303       3    8.0500         0
# 1304       1  108.9000         1
# 1305       3    7.2500         0
# 1306       3    8.0500         0
# 1307       3   22.3583         0
#
# [1308 rows x 3 columns]

# %%
# Out:
#       Pclass      Fare  Survived
# 0          3    7.2500         0
# 1          1   71.2833         1
# 2          3    7.9250         1
# 3          1   53.1000         1
# 4          3    8.0500         0
# ...      ...       ...       ...
# 1303       3    8.0500         0
# 1304       1  108.9000         1
# 1305       3    7.2500         0
# 1306       3    8.0500         0
# 1307       3   22.3583         0
#
# [1308 rows x 3 columns]

# %% [markdown]
# **Check the null value**

# %%
#code here
df.isnull().sum()
# Out:
# Pclass      0
# Fare        0
# Survived    0
# dtype: int64

# %%
# Out:
# Pclass      0
# Fare        0
# Survived    0
# dtype: int64

# %% [markdown]
# **Plot the data**

# %%
#code here
plt.scatter(df.Fare,df.Survived,color='red', marker='+')

plt.show()

# %% [markdown]
# **Separate the Features a target in x and y**

# %%
#code here
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df[['Fare']],df.Survived,train_size=0.8,random_state=2)

# %% [markdown]
# **Split the train and test data**

# %%
#code here
x_train
# Out:
#           Fare
# 126     7.7500
# 738     7.8958
# 379     7.7750
# 1251   37.0042
# 116     7.7500
# ...        ...
# 466     0.0000
# 299   247.5208
# 493    49.5042
# 527   221.7792
# 1192   21.0000
#
# [1046 rows x 1 columns]

# %%
x_test
# Out:
#           Fare
# 293     8.8500
# 823    12.4750
# 407    18.7500
# 724    53.1000
# 1206  146.5208
# ...        ...
# 333    18.0000
# 640     7.8542
# 1248    7.7500
# 273    29.7000
# 512    26.2875
#
# [262 rows x 1 columns]

# %%
y_train
# Out:
# 126     0
# 738     0
# 379     0
# 1251    1
# 116     0
#        ..
# 466     0
# 299     1
# 493     0
# 527     0
# 1192    0
# Name: Survived, Length: 1046, dtype: int64

# %%
y_test
# Out:
# 293     0
# 823     1
# 407     1
# 724     1
# 1206    0
#        ..
# 333     0
# 640     0
# 1248    0
# 273     0
# 512     1
# Name: Survived, Length: 262, dtype: int64

# %% [markdown]
# **Make the model Binary logistic regression model**

# %%
#code here
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %% [markdown]
# **Check the model score**

# %%
#code here
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
type(x_test)
# Out:
# pandas.core.frame.DataFrame

# %%
y_pred=model.predict(x_test)
y_pred.shape
# Out:
# (262,)

# %%
model.score(x_test,y_test)
# Out:
# 0.6412213740458015

# %%
model.predict([[100]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])
